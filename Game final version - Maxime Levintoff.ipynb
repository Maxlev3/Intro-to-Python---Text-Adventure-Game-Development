# %%
import random
import time
import sys
from sys import exit
import textwrap as tw
from colorama import Fore, Back, Style

# Introduction
"""
Author: Maxime Levintoff
Date: 17th October 2019

"""
"""
Docstring:
    This game was created for an assingment at Hult International Business School.
    It is an escape room in a text-game style.
    The goal is to escape! You just need a bit of logic...
    
    Stage 1: Ready?
    Stage 2: Stay or not
    Stage 3: Open the door
    Stage 4: Door choice
    Stage 5: Fight,run or screem
    
Known bugs: none

"""
ans = ["yes", "no"]
options = ["rock", "a rock", "hairpin", "a hairpin", "scissors", "a pair of scissors"]
ans1 = ["red door","the red door","steel door","the steel door","the dark door","dark door"]
ans2 = ["scream","fight","run"]


def game_start():
    global player_name
    global psycho_name
    print(Fore.RED +Back.BLACK +"""
 ██▓███    ██████ ▓██   ██▓ ▄████▄   ██░ ██  ▒█████    ██████  ▄████▄   ▄▄▄       ██▓███  ▓█████ 
▓██░  ██▒▒██    ▒  ▒██  ██▒▒██▀ ▀█  ▓██░ ██▒▒██▒  ██▒▒██    ▒ ▒██▀ ▀█  ▒████▄    ▓██░  ██▒▓█   ▀ 
▓██░ ██▓▒░ ▓██▄     ▒██ ██░▒▓█    ▄ ▒██▀▀██░▒██░  ██▒░ ▓██▄   ▒▓█    ▄ ▒██  ▀█▄  ▓██░ ██▓▒▒███   
▒██▄█▓▒ ▒  ▒   ██▒  ░ ▐██▓░▒▓▓▄ ▄██▒░▓█ ░██ ▒██   ██░  ▒   ██▒▒▓▓▄ ▄██▒░██▄▄▄▄██ ▒██▄█▓▒ ▒▒▓█  ▄ 
▒██▒ ░  ░▒██████▒▒  ░ ██▒▓░▒ ▓███▀ ░░▓█▒░██▓░ ████▓▒░▒██████▒▒▒ ▓███▀ ░ ▓█   ▓██▒▒██▒ ░  ░░▒████▒
▒▓▒░ ░  ░▒ ▒▓▒ ▒ ░   ██▒▒▒ ░ ░▒ ▒  ░ ▒ ░░▒░▒░ ▒░▒░▒░ ▒ ▒▓▒ ▒ ░░ ░▒ ▒  ░ ▒▒   ▓▒█░▒▓▒░ ░  ░░░ ▒░ ░
░▒ ░     ░ ░▒  ░ ░ ▓██ ░▒░   ░  ▒    ▒ ░▒░ ░  ░ ▒ ▒░ ░ ░▒  ░ ░  ░  ▒     ▒   ▒▒ ░░▒ ░      ░ ░  ░
░░       ░  ░  ░   ▒ ▒ ░░  ░         ░  ░░ ░░ ░ ░ ▒  ░  ░  ░  ░          ░   ▒   ░░          ░   
               ░   ░ ░     ░ ░       ░  ░  ░    ░ ░        ░  ░ ░            ░  ░            ░  ░
                   ░ ░     ░                                  ░                                  
""") # Color made using colorama module
    print(Style.RESET_ALL)
    print("Welcome to Psychoscape!")
    input("'<Press any key to continue>\n'")
    player_name = input("Hello there! What is your name?\n")
    print("") # Used to make the text more readable
    print(f"Welcome to Psychoscape {player_name}!")
    time.sleep(0.3)
    psycho_name = input("Who is the scariest psychopath you've met?\n")
    print("")
    print("I hope you have a strong stomach!")
    question1()
# Question 1
    
def question1():
    question = "".lower().strip
    while question not in ans:
      question_1 = input("Are you ready? (yes/no)\n")
      print("")
      if question_1.lower().strip() == "yes":
        print("That's amazing. Let's begin!")
        time.sleep(0.7) # Slow down the print function
        print(f'{player_name}, you recently had a burnout and quit your job!')
        time.sleep(0.7)
        print("You decided to go backpacking in Thailand.")
        time.sleep(0.7)
        print("")
        print("You arrived yesterday and went for a few drinks in the evening.")
        time.sleep(0.7)
        print("""You're waking up... Your head is heavy.
You don't remember what happened yesterday.""")
        time.sleep(0.7)
        print("")
        print("""You start looking aroung and realize that you're not in your room
and that you've got a surgery over night.""")
        time.sleep(0.7)
        print(f"You've been kidnapped and {psycho_name} probably stole your kidney.")
        print("")
        question2() #Call question2
      elif question_1.lower().strip() == "no":
        print("That's sad! See you soon...")
        exit()# Exit the game
      else:
        print("yes or no, that's not hard. You can do it!")
        print("")
        question1() #Call question1

#Question 2
def question2():
      question_2 = input(f"""Do you want to stay here
and wait for {psycho_name} to come back? (yes/no)\n""")
      if question_2.lower().strip() == "no":
          print("")
          print("That's what I thought. Let's go!")
          print("")
          time.sleep(0.5)
          round_1()
      elif question_2.lower().strip() == "yes":
        print("Too bad!")
        time.sleep(0.5)
        print(f"After a few minutes, {psycho_name} is back and so, you're DEAD {player_name} ...")
        print(Fore.RED +"""
 ______   _______  _______  ______  
(  __  \ (  ____ \(  ___  )(  __  \ 
| (  \  )| (    \/| (   ) || (  \  )
| |   ) || (__    | (___) || |   ) |
| |   | ||  __)   |  ___  || |   | |
| |   ) || (      | (   ) || |   ) |
| (__/  )| (____/\| )   ( || (__/  )
(______/ (_______/|/     \|(______/ 
                                    
""")
        print(Style.RESET_ALL)
        fail()
      else:
        print(f"What did you say {player_name}?")
        question2()

 #round_1
def round_1():
    print('You look around in the room for something that could help you escape.')
    print("")
    time.sleep(0.5)
    print('There is a rock,a hairpin and a pair of scissors')
    round1 = "".lower().strip()
    while round1 not in options:
        round1 = input(f'What do you want to use?\n')
        print("")
        if round1.lower().strip() == "rock" or round1.lower().strip() == "a rock":
            print("You throw the rock at the door ")
            time.sleep(0.5)
            print("and it comes back right at your face")
            time.sleep(0.5)
            print(f"You're dead {player_name}...")
            print(Fore.RED +"""
 ______   _______  _______  ______  
(  __  \ (  ____ \(  ___  )(  __  \ 
| (  \  )| (    \/| (   ) || (  \  )
| |   ) || (__    | (___) || |   ) |
| |   | ||  __)   |  ___  || |   | |
| |   ) || (      | (   ) || |   ) |
| (__/  )| (____/\| )   ( || (__/  )
(______/ (_______/|/     \|(______/ 
                                    
""")
            print(Style.RESET_ALL)
            fail()
        elif round1.lower().strip() == "hairpin" or round1.lower().strip() == "a hairpin":
            print("With your thief skills, you managed to open the door!")
            print("")
            round_2()
        elif round1.lower().strip() == "pair of scissors" or round1.lower().strip() == "a pair of scissors":
            print("""You try to open the door with the pair of scissors
but it makes too much noise.""")
            time.sleep(0.5)
            print(f"In other words, you're DEAD {player_name}...")
            print(Fore.RED +"""
 ______   _______  _______  ______  
(  __  \ (  ____ \(  ___  )(  __  \ 
| (  \  )| (    \/| (   ) || (  \  )
| |   ) || (__    | (___) || |   ) |
| |   | ||  __)   |  ___  || |   | |
| |   ) || (      | (   ) || |   ) |
| (__/  )| (____/\| )   ( || (__/  )
(______/ (_______/|/     \|(______/ 
                                    
""")
            print(Style.RESET_ALL)
            fail()
        else:
            print("a rock, a hairpin or a pair of scissors. Choose!")
            round_1() #Call round_1

#round_2
       
def round_2():
    print("You open the door and find youself in a room with 3 doors.")
    print("")
    time.sleep(0.5)
    print("""A red door with blood,
a dark door where you can see lights under,
and a steel door.""")
    quest = "".lower().strip
    while quest not in ans1:
        round2 = input(f"Which door, {player_name}!\n")
        print("")
        if round2.lower().strip() == "red door" or round2.lower().strip() == "the red door":
            print(f"There is blood everywhere. Why would you do that {player_name}???")
            time.sleep(0.5)
            print(f"You open the door and {psycho_name} is waiting for you")
            time.sleep(0.5)
            print(f"You're DEAD {player_name}...")
            time.sleep(0.5)
            print(Fore.RED +"""
 ______   _______  _______  ______  
(  __  \ (  ____ \(  ___  )(  __  \ 
| (  \  )| (    \/| (   ) || (  \  )
| |   ) || (__    | (___) || |   ) |
| |   | ||  __)   |  ___  || |   | |
| |   ) || (      | (   ) || |   ) |
| (__/  )| (____/\| )   ( || (__/  )
(______/ (_______/|/     \|(______/ 
                                    
""")
            print(Style.RESET_ALL)
            fail()
        elif round2.lower().strip() == "dark door" or round2.lower().strip() == "the dark door":
            print("Good job! You are out!")
            print("")
            time.sleep(0.5)
            print(f"Your eyes need a bit of time to adapt but you see {psycho_name} running towards you.")
            round_3() # Call round_3
        elif round2.lower().strip() == "steel door" or round2.lower().strip() == "the steel door":
            print("It's closed. Try another one!")
            time.sleep(0.5)
            
            round_2() # Call round_2
        else:
            print("What did you say? Let's try again! (e.g., pink door)")
            print("")
            round_2()

#round_3
def round_3():
    print("You have three options.")
    print("")
    time.sleep(0.5)
    print(f"Fight {psycho_name}, run and hide in the shops around, scream for your life")
    print("")
    quest1 = "".lower().strip
    while quest1 not in ans2:
        round3 = input("What do you want to do? Fight, run or scream?\n")
        if round3.lower().strip() == "fight":
            print("Who do you think you are?")
            time.sleep(0.5)
            print(f"{psycho_name} catches you and send you back to your cell")
            question2()
        elif round3.lower().strip() == "run":
            print("Smart! After a few minutes, you find a policeman!")
            time.sleep(0.5)
            print("You're safe!")
            time.sleep(0.5)
            print(Fore.WHITE +Back.GREEN +"""
 ______   _______  _______           _______  _ 
(  ___ \ (  ____ )(  ___  )|\     /|(  ___  )( )
| (   ) )| (    )|| (   ) || )   ( || (   ) || |
| (__/ / | (____)|| (___) || |   | || |   | || |
|  __ (  |     __)|  ___  |( (   ) )| |   | || |
| (  \ \ | (\ (   | (   ) | \ \_/ / | |   | |(_)
| )___) )| ) \ \__| )   ( |  \   /  | (___) | _ 
|/ \___/ |/   \__/|/     \|   \_/   (_______)(_)""")
            time.sleep(2)
            exit()
        elif round3.lower().strip() == "scream":
            print(f"{psycho_name} catches you in less than a minute...")
            time.sleep(0.5)
            print(f"You're DEAD {player_name}...")
            print(Fore.RED +"""
 ______   _______  _______  ______  
(  __  \ (  ____ \(  ___  )(  __  \ 
| (  \  )| (    \/| (   ) || (  \  )
| |   ) || (__    | (___) || |   ) |
| |   | ||  __)   |  ___  || |   | |
| |   ) || (      | (   ) || |   ) |
| (__/  )| (____/\| )   ( || (__/  )
(______/ (_______/|/     \|(______/                                    
""")
            print(Style.RESET_ALL)
            fail()
        else:
            print("What did you say?")
            round_3()


def fail(): # Fail function with the option to replay the game
    fail_inp = input(f"You are Dead! Do you wanna play again?: \n1. Play Again \n2. Quit\n").lower()
    if "1" in fail_inp or "play" in fail_inp:
        question1()

    else:
        exit()

# Start the game
game_start()
# Out:
#  ██▓███    ██████ ▓██   ██▓ ▄████▄   ██░ ██  ▒█████    ██████  ▄████▄   ▄▄▄       ██▓███  ▓█████
# ▓██░  ██▒▒██    ▒  ▒██  ██▒▒██▀ ▀█  ▓██░ ██▒▒██▒  ██▒▒██    ▒ ▒██▀ ▀█  ▒████▄    ▓██░  ██▒▓█   ▀
# ▓██░ ██▓▒░ ▓██▄     ▒██ ██░▒▓█    ▄ ▒██▀▀██░▒██░  ██▒░ ▓██▄   ▒▓█    ▄ ▒██  ▀█▄  ▓██░ ██▓▒▒███
# ▒██▄█▓▒ ▒  ▒   ██▒  ░ ▐██▓░▒▓▓▄ ▄██▒░▓█ ░██ ▒██   ██░  ▒   ██▒▒▓▓▄ ▄██▒░██▄▄▄▄██ ▒██▄█▓▒ ▒▒▓█  ▄
# ▒██▒ ░  ░▒██████▒▒  ░ ██▒▓░▒ ▓███▀ ░░▓█▒░██▓░ ████▓▒░▒██████▒▒▒ ▓███▀ ░ ▓█   ▓██▒▒██▒ ░  ░░▒████▒
# ▒▓▒░ ░  ░▒ ▒▓▒ ▒ ░   ██▒▒▒ ░ ░▒ ▒  ░ ▒ ░░▒░▒░ ▒░▒░▒░ ▒ ▒▓▒ ▒ ░░ ░▒ ▒  ░ ▒▒   ▓▒█░▒▓▒░ ░  ░░░ ▒░ ░
# ░▒ ░     ░ ░▒  ░ ░ ▓██ ░▒░   ░  ▒    ▒ ░▒░ ░  ░ ▒ ▒░ ░ ░▒  ░ ░  ░  ▒     ▒   ▒▒ ░░▒ ░      ░ ░  ░
# ░░       ░  ░  ░   ▒ ▒ ░░  ░         ░  ░░ ░░ ░ ░ ▒  ░  ░  ░  ░          ░   ▒   ░░          ░
#                ░   ░ ░     ░ ░       ░  ░  ░    ░ ░        ░  ░ ░            ░  ░            ░  ░
#                    ░ ░     ░                                  ░
#
#
# Welcome to Psychoscape!
